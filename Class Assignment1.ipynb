# %%
from Multiplefunctions import SubfieldsInAI
# Out:
# Your age: 20
# Your gender: male
# subject 1= 98
# subject 2= 87
# subject 3= 95
# subject 4= 95
# subject 5= 93

# %%
SubfieldsInAI.Subfields()
# Out:
# Sub-fields in AI are:
# Machine Learning
# Neural Networks
# Vision
# Robotics
# Speech Processing
# Natural Language Processing

# %%
SubfieldsInAI.Elegible('male', 20)
# Out:
# Not Eligible

# %%
SubfieldsInAI.OddEven()
# Out:
# Enter the number is: 52452
# 52452 is Even Number

# %%
SubfieldsInAI.percentage()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 SubfieldsInAI.percentage()
#
# File C:\Hope AI\Python\Multiplefunctions.py:36, in SubfieldsInAI.percentage()
#      35 def percentage():
# ---> 36     print ("Total :", Total)
#      37     print ("Percentage :", Percentage)
#
# NameError: name 'Total' is not defined

# %%
SubfieldsInAI.triangle()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 SubfieldsInAI.triangle()
#
# File C:\Hope AI\Python\Multiplefunctions.py:46, in SubfieldsInAI.triangle()
#      45 def triangle():
# ---> 46     print("Area Of Triangle:", AreaOfTriangle)
#      47     print("Perimeter Of Triangle:", PerimeterOfTriangle)
#
# NameError: name 'AreaOfTriangle' is not defined
